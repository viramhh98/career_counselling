# %%
import pandas as pd
user_input=[]

def take_skill_inputs():
    skills = [
        "Database Fundamentals", "Computer Architecture", "Distributed Computing Systems",
        "Cyber Security", "Networking", "Software Development", "Programming Skills",
        "Project Management", "Computer Forensics Fundamentals", "Technical Communication",
        "AI ML", "Software Engineering", "Business Analysis", "Communication skills",
        "Data Science", "Troubleshooting skills", "Graphics Designing"
    ]
    proficiency_levels = ["Not interested", "Poor", "Beginner", "Average", "Excellent","proffesional"]
    skill_levels = {}
    for skill in skills:
        print(f"\n\nFor skill: {skill}")
        for i, level in enumerate(proficiency_levels, 1):
            print(f"{i}. {level}")
        choice = int(input("Enter proficiency level (1-6): "))
        while choice < 1 or choice > 6:
            print("Invalid input. Please enter a number between 1 and 6.")
            choice = int(input("Enter proficiency level (1-6): "))
        skill_levels[skill] = proficiency_levels[choice - 1]
        user_input.append(choice)

    return skill_levels

skills_levels = take_skill_inputs()
print("\n\nSkill levels entered:")
for skill, level in skills_levels.items():
    print(f"{skill}: {level}")


data=pd.read_csv("dataset9000 - Copy.csv")
# Out:
# For skill: Database Fundamentals
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  1
# For skill: Computer Architecture
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  2
# For skill: Distributed Computing Systems
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  3
# For skill: Cyber Security
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  4
# For skill: Networking
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  5
# For skill: Software Development
# 1. Not interested
# 2. Poor
# 3. Beginner
# 4. Average
# 5. Excellent
# 6. proffesional
# Enter proficiency level (1-6):  6
# For skill: Programming Skills
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming 'X' contains the input features (skills) and 'y' contains the output (roles)
x=data.iloc[:, :-1 ].values
y=data.iloc[:, -1 ].values

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# # Assuming 'X' contains the input features (skills) and 'y' contains the output (roles)
# x=data.iloc[:, :-1 ].values
# y=data.iloc[:, -1 ].values


X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Instantiate label encoder for output (roles)
label_encoder = LabelEncoder()

# Encode categorical output (roles) into numerical labels
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Instantiate the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the classifier on the training data
rf_classifier.fit(X_train, y_train_encoded)

# Make predictions on the test data
y_pred = rf_classifier.predict(X_test)

# Decode numerical predictions back to categorical labels
y_pred_decoded = label_encoder.inverse_transform(y_pred)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred_decoded)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7162309368191722

# %%
# Assume user_input is the input data provided by the user
import numpy as np

new_data = np.array(user_input)  # Your single row of data
new_data_reshaped = new_data.reshape(1, -1)  # Reshape the array to (1, n_features)

user_input = new_data_reshaped  # Replace this with the actual user input2


# Use the trained model to make predictions on the user input
predicted_label = rf_classifier.predict(user_input)

# Optionally, decode the predicted label if necessary
predicted_role = label_encoder.inverse_transform(predicted_label)

# Print the predicted role
print("Predicted Role:", predicted_role)
# Out:
# Predicted Role: ['Software Developer']

# %%
class RoleMethods:
    def AI_ML_Specialist(self):
     description = """
Welcome to the AI/ML Specialist Guide!

As an AI/ML Specialist, you are at the forefront of innovation, utilizing artificial intelligence and machine learning techniques to solve complex problems and drive business success.

**Description:**
- Develop machine learning models and algorithms.
- Implement and deploy AI solutions to automate processes and improve efficiency.
- Analyze large datasets to extract meaningful insights and patterns.
- Collaborate with cross-functional teams to integrate AI/ML into products and services.

**Salary:**
The average salary for AI/ML Specialists ranges from $80,000 to $120,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for AI/ML Specialists include Google, Facebook, Amazon, and Microsoft.

**Skills Required:**
- Proficiency in machine learning libraries such as TensorFlow, PyTorch, or scikit-learn.
- Strong programming skills in Python or R.
- Knowledge of deep learning techniques and neural networks.
- Experience with data preprocessing, feature engineering, and model evaluation.
- Ability to communicate complex concepts and findings to non-technical stakeholders.

Join the cutting-edge field of artificial intelligence and machine learning, and unleash the power of data-driven insights today!
"""
     print(description)


    def API_Specialist(self):
        description = """
Welcome to the API Specialist Guide!

As an API Specialist, you are responsible for designing, developing, and maintaining application programming interfaces (APIs) to enable seamless communication between different software components and systems.

**Description:**
- Design and implement RESTful APIs for web and mobile applications.
- Develop API documentation and specifications for developers.
- Ensure API security and authentication mechanisms are in place.
- Collaborate with cross-functional teams to integrate APIs into software products.
- Monitor and troubleshoot API performance and reliability issues.

**Salary:**
The average salary for API Specialists ranges from $70,000 to $100,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for API Specialists include Twilio, Stripe, Postman, and MuleSoft.

**Skills Required:**
- Proficiency in programming languages such as Python, JavaScript, or Java.
- Experience with API design standards and best practices.
- Knowledge of API management platforms and tools (e.g., Swagger, Postman).
- Understanding of HTTP protocols and RESTful principles.
- Strong problem-solving and troubleshooting skills.

Join the dynamic world of API development and empower seamless integration between software systems today!
"""
        print(description)

    def Application_Support_Engineer(self):
        description = """
Welcome to the Application Support Engineer Guide!

As an Application Support Engineer, you are responsible for ensuring the smooth operation and performance of software applications. Your role involves troubleshooting issues, providing technical support to end-users, and collaborating with development teams to implement solutions.

**Description:**
- Provide technical support and troubleshooting assistance to end-users experiencing software issues.
- Diagnose and resolve software application problems, including bugs, errors, and performance issues.
- Escalate complex issues to the appropriate teams for resolution and follow up to ensure timely resolution.
- Collaborate with development teams to implement fixes, patches, and updates to software applications.
- Document support processes, solutions, and best practices for future reference.

**Salary:**
The average salary for Application Support Engineers ranges from $60,000 to $90,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Application Support Engineers include Oracle, SAP, Salesforce, and ServiceNow.

**Skills Required:**
- Strong technical knowledge of software applications and systems.
- Proficiency in troubleshooting methodologies and tools.
- Excellent communication and customer service skills.
- Ability to work effectively in a fast-paced environment and handle multiple tasks simultaneously.
- Familiarity with scripting languages such as Python, PowerShell, or Shell scripting.

Join the exciting field of application support and make a difference in ensuring the reliability and usability of software applications today!
"""
        print(description)


    def Business_Analyst(self):
        description = """
Welcome to the Business Analyst Guide!

As a Business Analyst, you play a crucial role in analyzing business processes, identifying opportunities for improvement, and facilitating decision-making within organizations. Your responsibilities include gathering and documenting requirements, analyzing data, and communicating insights to stakeholders.

**Description:**
- Gather and document business requirements from stakeholders and end-users.
- Analyze business processes, workflows, and systems to identify areas for improvement and optimization.
- Conduct data analysis to uncover insights and trends that drive business decisions.
- Collaborate with cross-functional teams to develop and implement solutions that meet business needs.
- Facilitate communication between business stakeholders and technical teams to ensure alignment and understanding of project objectives.

**Salary:**
The average salary for Business Analysts ranges from $70,000 to $100,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Business Analysts include McKinsey & Company, Deloitte, Accenture, and IBM.

**Skills Required:**
- Strong analytical and problem-solving skills.
- Proficiency in data analysis tools such as Excel, SQL, or Tableau.
- Excellent communication and interpersonal skills.
- Ability to translate business requirements into technical specifications.
- Knowledge of business process modeling and documentation techniques.

Embark on an exciting career as a Business Analyst and make a meaningful impact on organizational success today!
"""
        print(description)


    def Customer_Service_Executive(self):
        description = """
Welcome to the Customer Service Executive Guide!

As a Customer Service Executive, you play a vital role in ensuring customer satisfaction and loyalty by providing excellent service and support. Your responsibilities include handling customer inquiries, resolving issues, and maintaining positive relationships with clients.

**Description:**
- Respond promptly to customer inquiries via phone, email, or chat.
- Resolve customer complaints and issues in a timely and professional manner.
- Provide product information, pricing, and availability to customers.
- Process orders, returns, and exchanges accurately and efficiently.
- Maintain accurate records of customer interactions and transactions.

**Salary:**
The average salary for Customer Service Executives ranges from $30,000 to $50,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Customer Service Executives include Amazon, Apple, Zappos, and Southwest Airlines.

**Skills Required:**
- Excellent communication and interpersonal skills.
- Patience and empathy when dealing with customers.
- Strong problem-solving abilities.
- Ability to multitask and prioritize tasks effectively.
- Knowledge of customer service software and CRM systems.

Join the ranks of skilled Customer Service Executives and make a difference in customer satisfaction today!
"""
        print(description)


    def Cyber_Security_Specialist(self):
        description = """
Welcome to the Cyber Security Specialist Guide!

As a Cyber Security Specialist, you are responsible for protecting computer systems, networks, and data from cyber threats and attacks. Your role involves implementing security measures, monitoring systems for vulnerabilities, and responding to incidents to ensure the confidentiality, integrity, and availability of information.

**Description:**
- Design and implement security measures to protect computer systems, networks, and data.
- Conduct regular security assessments and audits to identify vulnerabilities and risks.
- Monitor networks and systems for security breaches or suspicious activity.
- Respond to security incidents and breaches, including forensic investigation and incident response.
- Develop and implement security policies, procedures, and best practices.

**Salary:**
The average salary for Cyber Security Specialists ranges from $80,000 to $120,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Cyber Security Specialists include Google, Microsoft, Amazon Web Services, and IBM.

**Skills Required:**
- In-depth knowledge of cybersecurity principles, technologies, and best practices.
- Proficiency in security tools such as firewalls, intrusion detection systems, and antivirus software.
- Strong analytical and problem-solving skills.
- Excellent communication and teamwork abilities.
- Ability to stay updated on the latest cybersecurity threats and trends.

Join the front lines of cybersecurity defense and protect organizations from cyber threats as a Cyber Security Specialist!
"""
        print(description)


    def Data_Scientist(self):
        description = """
Welcome to the Data Scientist Guide!

As a Data Scientist, you are responsible for analyzing complex data sets to uncover insights and trends that drive business decisions and innovation. Your role involves collecting, cleaning, and transforming data, applying statistical and machine learning techniques, and communicating findings to stakeholders.

**Description:**
- Collect, clean, and preprocess large and complex data sets from various sources.
- Apply statistical analysis and machine learning algorithms to extract insights and patterns from data.
- Develop predictive models and algorithms to solve business problems and improve decision-making.
- Visualize data and communicate findings to non-technical stakeholders.
- Collaborate with cross-functional teams to identify opportunities and drive data-driven solutions.

**Salary:**
The average salary for Data Scientists ranges from $90,000 to $150,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Data Scientists include Google, Facebook, Amazon, and Microsoft.

**Skills Required:**
- Proficiency in programming languages such as Python, R, or SQL.
- Strong understanding of statistical analysis and machine learning algorithms.
- Experience with data visualization tools such as Matplotlib, Seaborn, or Tableau.
- Excellent problem-solving and analytical skills.
- Effective communication and storytelling abilities.

Unlock the power of data and make an impact as a Data Scientist in today's data-driven world!
"""
        print(description)


    def Database_Administrator(self):
        description = """
Welcome to the Database Administrator Guide!

As a Database Administrator (DBA), you are responsible for managing and maintaining databases to ensure their security, performance, and availability. Your role involves designing database structures, implementing data security measures, and optimizing database performance.

**Description:**
- Design and implement database structures, schemas, and tables.
- Configure and maintain database management systems (DBMS) for optimal performance.
- Monitor database performance and troubleshoot issues to ensure reliability and availability.
- Implement data security measures, such as access controls and encryption, to protect sensitive information.
- Perform database backups, restores, and disaster recovery procedures.
- Collaborate with developers and system administrators to integrate databases with applications and systems.

**Salary:**
The average salary for Database Administrators ranges from $70,000 to $110,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Database Administrators include Oracle, Microsoft, IBM, and Amazon Web Services (AWS).

**Skills Required:**
- Proficiency in database management systems such as Oracle, MySQL, SQL Server, or PostgreSQL.
- Knowledge of database design principles and normalization techniques.
- Experience with database administration tasks, such as backup and recovery, performance tuning, and security management.
- Strong problem-solving and troubleshooting skills.
- Excellent communication and collaboration abilities.

Master the art of database management and become a trusted Database Administrator in the world of information technology!
"""
        print(description)


    def Graphics_Designer(self):
        description = """
Welcome to the Graphics Designer Guide!

As a Graphics Designer, you are responsible for creating visual concepts and designs for various digital and print media. Your role involves using computer software to generate graphics, illustrations, and layouts that communicate messages effectively.

**Description:**
- Create visual concepts and designs for advertisements, brochures, websites, and other marketing materials.
- Use graphic design software such as Adobe Photoshop, Illustrator, and InDesign to produce high-quality graphics and illustrations.
- Collaborate with clients or art directors to understand their design requirements and preferences.
- Develop and present design proposals and mockups to clients for approval.
- Revise and refine designs based on client feedback and project requirements.
- Prepare final artwork files for printing or digital publishing.

**Salary:**
The average salary for Graphics Designers ranges from $40,000 to $70,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Graphics Designers include Adobe, Apple, Google, and Facebook.

**Skills Required:**
- Proficiency in graphic design software such as Adobe Creative Suite (Photoshop, Illustrator, InDesign).
- Creativity and artistic ability to conceptualize and develop visually appealing designs.
- Attention to detail and a keen eye for aesthetics and layout.
- Strong communication and collaboration skills to work effectively with clients and team members.
- Ability to manage multiple projects and meet deadlines in a fast-paced environment.

Explore the world of visual communication and unleash your creativity as a Graphics Designer today!
"""
        print(description)


    def Hardware_Engineer(self):
        description = """
Welcome to the Hardware Engineer Guide!

As a Hardware Engineer, you are involved in the design, development, and testing of electronic hardware components and systems. Your role encompasses designing circuit boards, testing prototypes, and troubleshooting hardware issues to ensure optimal performance.

**Description:**
- Design and develop electronic circuits and components for various hardware systems.
- Conduct feasibility studies and technical evaluations to assess the viability of hardware designs.
- Prototype and test hardware designs to ensure functionality, reliability, and compliance with specifications.
- Collaborate with cross-functional teams, including software engineers and product designers, to integrate hardware with software applications.
- Troubleshoot hardware issues and conduct root cause analysis to identify and resolve problems.
- Document hardware designs, specifications, and test results for reference and future development.

**Salary:**
The average salary for Hardware Engineers ranges from $60,000 to $100,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Hardware Engineers include Apple, Intel, NVIDIA, and Qualcomm.

**Skills Required:**
- Proficiency in electronic design tools such as Altium Designer, Cadence Allegro, or OrCAD.
- Knowledge of digital and analog circuit design, PCB layout, and signal integrity analysis.
- Familiarity with microcontrollers, FPGAs, and embedded systems programming.
- Strong problem-solving skills and attention to detail.
- Effective communication and collaboration abilities to work in multidisciplinary teams.

Embark on a rewarding career in hardware engineering and contribute to the development of cutting-edge technology!
"""
        print(description)


    def Helpdesk_Engineer(self):
        description = """
Welcome to the Helpdesk Engineer Guide!

As a Helpdesk Engineer, you are responsible for providing technical support and assistance to end-users experiencing IT-related issues. Your role involves troubleshooting hardware and software problems, resolving technical issues, and ensuring smooth operation of IT systems.

**Description:**
- Respond to user inquiries and provide technical assistance via phone, email, or in-person.
- Troubleshoot hardware and software issues, diagnose problems, and implement solutions.
- Install, configure, and maintain computer systems, software applications, and peripherals.
- Document support incidents, resolutions, and procedures for reference and knowledge sharing.
- Collaborate with IT teams to escalate and resolve complex technical issues.
- Provide training and guidance to users on IT tools, systems, and best practices.

**Salary:**
The average salary for Helpdesk Engineers ranges from $40,000 to $60,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Helpdesk Engineers include Microsoft, IBM, Dell, and HP.

**Skills Required:**
- Strong technical knowledge of computer hardware, software, and operating systems.
- Excellent problem-solving and troubleshooting skills.
- Customer service orientation and ability to communicate technical information clearly to non-technical users.
- Familiarity with IT service management tools such as ServiceNow or Zendesk.
- Ability to work independently and collaboratively in a fast-paced environment.

Join the helpdesk team and make a difference by providing efficient IT support to users!
"""
        print(description)


    def Information_Security_Specialist(self):
        description = """
Welcome to the Information Security Specialist Guide!

As an Information Security Specialist, you play a critical role in protecting an organization's information assets from security threats and breaches. Your responsibilities include implementing security measures, conducting risk assessments, and developing strategies to safeguard sensitive data.

**Description:**
- Develop and implement information security policies, procedures, and protocols to safeguard organizational assets.
- Conduct regular security audits and risk assessments to identify vulnerabilities and mitigate potential threats.
- Monitor and analyze security events and incidents, investigate security breaches, and recommend corrective actions.
- Implement and manage security technologies such as firewalls, intrusion detection systems, and encryption tools.
- Provide security awareness training to employees and promote a culture of security awareness throughout the organization.
- Stay up-to-date with the latest security trends, threats, and best practices to continuously enhance security posture.

**Salary:**
The average salary for Information Security Specialists ranges from $80,000 to $120,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Information Security Specialists include Google, Microsoft, Amazon, and IBM.

**Skills Required:**
- Strong knowledge of information security principles, standards, and best practices.
- Proficiency in security technologies and tools such as SIEM, IDS/IPS, DLP, and endpoint security solutions.
- Experience with risk management methodologies and regulatory compliance requirements (e.g., GDPR, HIPAA, PCI DSS).
- Excellent analytical and problem-solving skills.
- Effective communication and collaboration skills to work with cross-functional teams.

Join the information security field and contribute to protecting valuable assets from cyber threats!
"""
        print(description)


    def Networking_Engineer(self):
        description = """
Welcome to the Networking Engineer Guide!

As a Networking Engineer, you are responsible for designing, implementing, and maintaining computer networks to ensure efficient communication and connectivity. Your role involves configuring network devices, troubleshooting issues, and optimizing network performance.

**Description:**
- Design, deploy, and maintain computer networks, including LANs, WANs, and WLANs.
- Configure network devices such as routers, switches, firewalls, and access points to ensure proper communication and security.
- Monitor network performance and troubleshoot network issues, including connectivity problems, slow performance, and security breaches.
- Implement network security measures, such as firewalls, VPNs, and intrusion detection systems, to protect against unauthorized access and cyber threats.
- Collaborate with cross-functional teams to plan and implement network infrastructure upgrades and expansions.
- Stay up-to-date with the latest networking technologies, standards, and best practices to continuously improve network reliability and performance.

**Salary:**
The average salary for Networking Engineers ranges from $60,000 to $100,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Networking Engineers include Cisco, Juniper Networks, Arista Networks, and Amazon Web Services.

**Skills Required:**
- Strong knowledge of networking protocols and technologies, including TCP/IP, DNS, DHCP, VLANs, and routing protocols (e.g., OSPF, BGP).
- Proficiency in network hardware and software, such as routers, switches, firewalls, and network management tools.
- Experience with network troubleshooting and diagnostic tools, such as Wireshark and ping.
- Excellent problem-solving and analytical skills.
- Effective communication and collaboration skills to work with team members and stakeholders.

Embark on a rewarding career in networking engineering and help organizations build and maintain reliable network infrastructures!
"""
        print(description)


    def Project_Manager(self):
        description = """
Welcome to the Project Manager Guide!

As a Project Manager, you are responsible for planning, executing, and overseeing projects from initiation to completion. Your role involves defining project goals, managing resources, and ensuring that projects are delivered on time, within budget, and according to specifications.

**Description:**
- Define project objectives, scope, and deliverables in collaboration with stakeholders.
- Develop project plans, schedules, and budgets to allocate resources effectively and meet project milestones.
- Lead project teams, assign tasks, and monitor progress to ensure timely completion of deliverables.
- Identify and mitigate project risks, issues, and dependencies to minimize disruptions and delays.
- Communicate project status, updates, and outcomes to stakeholders through regular meetings, reports, and presentations.
- Evaluate project performance and outcomes against established metrics and KPIs to drive continuous improvement.
- Foster a collaborative and supportive team environment to maximize productivity and engagement.

**Salary:**
The average salary for Project Managers ranges from $70,000 to $120,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Project Managers include Google, Apple, Microsoft, and IBM.

**Skills Required:**
- Strong leadership and management skills to motivate and guide project teams.
- Excellent communication and interpersonal skills to interact with stakeholders and resolve conflicts.
- Proficiency in project management tools and methodologies, such as Agile, Scrum, and Kanban.
- Solid understanding of project management principles, processes, and best practices.
- Problem-solving and decision-making abilities to address challenges and make informed decisions.
- Organizational and time management skills to prioritize tasks and manage multiple projects simultaneously.

Embark on a rewarding career in project management and lead successful projects that drive business growth and innovation!
"""
        print(description)

    def Software_Developer(self):
        description = """
Welcome to the Software Developer Guide!

As a Software Developer, you are responsible for designing, developing, and maintaining software applications that meet the needs of users and businesses. Your job involves writing code, debugging software, and collaborating with cross-functional teams to deliver high-quality solutions.

**Description:**
- Analyze user requirements and design software solutions to meet their needs.
- Write clean, efficient, and maintainable code using programming languages such as Python, Java, C++, or JavaScript.
- Test and debug software to identify and fix bugs, ensuring quality and reliability.
- Collaborate with product managers, designers, and other stakeholders to define project requirements and timelines.
- Keep up-to-date with the latest technologies, trends, and best practices in software development.
- Participate in code reviews, discussions, and knowledge sharing sessions to enhance team productivity and quality.

**Salary:**
The average salary for Software Developers ranges from $70,000 to $120,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Software Developers include Google, Microsoft, Amazon, and Facebook.

**Skills Required:**
- Proficiency in one or more programming languages and frameworks, such as Python/Django, Java/Spring, or JavaScript/React.
- Strong problem-solving skills and the ability to think logically and analytically.
- Familiarity with software development methodologies, such as Agile or Scrum.
- Good communication and teamwork abilities, with the capacity to collaborate effectively with others.
- Attention to detail and a commitment to writing clean, well-documented code.
- Adaptability and willingness to learn new technologies and tools as needed.

Embark on an exciting career in software development and make an impact by creating innovative solutions that drive business success!
"""
        print(description)

    
    def Software_tester(self):
        description = """
Welcome to the Software Tester Guide!

As a Software Tester, you play a crucial role in ensuring the quality and functionality of software applications. Your job involves identifying bugs, conducting tests, and collaborating with developers to enhance the user experience.

**Description:**
- Conduct software testing to identify and resolve bugs.
- Develop and execute test cases and scripts.
- Collaborate with development teams to improve software quality.
- Ensure compliance with quality standards and specifications.

**Salary:**
The average salary for Software Testers ranges from $50,000 to $80,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Software Testers include Google, Microsoft, Amazon, and IBM.

**Skills Required:**
- Strong analytical and problem-solving skills.
- Proficiency in testing tools such as Selenium, JUnit, or TestNG.
- Knowledge of programming languages like Java, Python, or C++.
- Excellent communication and teamwork abilities.
- Attention to detail and a passion for quality assurance.

Explore the exciting world of software testing and start your journey to becoming a skilled Software Tester today!
"""
        print(description)




    def Technical_Writer(self):
        description = """
Welcome to the Technical Writer Guide!

As a Technical Writer, you play a vital role in creating clear and concise documentation for technical products and processes. Your job involves researching, writing, and editing technical content to help users understand complex information easily.

**Description:**
- Research and gather information from subject matter experts, technical specifications, and other sources to understand the product or process.
- Write and edit technical documents, including user manuals, installation guides, API documentation, and troubleshooting guides.
- Organize and structure technical content to make it easy to navigate and understand, using appropriate formatting, headings, and diagrams.
- Collaborate with cross-functional teams, such as developers, engineers, and designers, to ensure accuracy and completeness of documentation.
- Review and revise existing documentation to keep it up-to-date with product changes, user feedback, and industry standards.
- Maintain a style guide and documentation templates to ensure consistency and quality across all written materials.

**Salary:**
The average salary for Technical Writers ranges from $60,000 to $90,000 per year, depending on experience and location.

**Best Companies:**
Some of the top companies for Technical Writers include Google, Microsoft, Amazon, and IBM.

**Skills Required:**
- Excellent writing and editing skills, with a focus on clarity, accuracy, and conciseness.
- Strong attention to detail and the ability to understand complex technical concepts and translate them into user-friendly language.
- Proficiency in documentation tools and software, such as Microsoft Word, Adobe FrameMaker, and Markdown.
- Knowledge of technical writing standards, such as the Microsoft Manual of Style and the Chicago Manual of Style.
- Familiarity with version control systems, content management systems, and collaboration tools.
- Ability to work independently and meet deadlines in a fast-paced, dynamic environment.

Join the exciting field of technical writing and contribute to the success of innovative products and technologies through effective documentation!
"""
        print(description)


    def execute_method(self, role):
        if role == "AI ML Specialist":
            self.AI_ML_Specialist()
        elif role == "API Specialist":
            self.API_Specialist()
        elif role == "Application Support Engineer":
            self.Application_Support_Engineer()
        elif role == "Business Analyst":
            self.Business_Analyst()
        elif role == "Customer Service Executive":
            self.Customer_Service_Executive()
        elif role == "Cyber Security Specialist":
            self.Cyber_Security_Specialist()
        elif role == "Data Scientist":
            self.Data_Scientist()
        elif role == "Database Administrator":
            self.Database_Administrator()
        elif role == "Graphics Designer":
            self.Graphics_Designer()
        elif role == "Hardware Engineer":
            self.Hardware_Engineer()
        elif role == "Helpdesk Engineer":
            self.Helpdesk_Engineer()
        elif role == "Information Security Specialist":
            self.Information_Security_Specialist()
        elif role == "Networking Engineer":
            self.Networking_Engineer()
        elif role == "Project Manager":
            self.Project_Manager()
        elif role == "Software Developer":
            self.Software_Developer()
        elif role == "Software tester":
            self.Software_tester()
        elif role == "Technical Writer":
            self.Technical_Writer()
        else:
            print("No method defined for this role")


# Create an instance of the class
role_methods = RoleMethods()
role_methods.execute_method(predicted_role)
# Out:
# Welcome to the Software Developer Guide!
#
# As a Software Developer, you are responsible for designing, developing, and maintaining software applications that meet the needs of users and businesses. Your job involves writing code, debugging software, and collaborating with cross-functional teams to deliver high-quality solutions.
#
# **Description:**
# - Analyze user requirements and design software solutions to meet their needs.
# - Write clean, efficient, and maintainable code using programming languages such as Python, Java, C++, or JavaScript.
# - Test and debug software to identify and fix bugs, ensuring quality and reliability.
# - Collaborate with product managers, designers, and other stakeholders to define project requirements and timelines.
# - Keep up-to-date with the latest technologies, trends, and best practices in software development.
# - Participate in code reviews, discussions, and knowledge sharing sessions to enhance team productivity and quality.
#
# ...
